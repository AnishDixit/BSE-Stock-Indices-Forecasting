# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('stocksdata.csv',index_col='Date',parse_dates=True)

# %%
print(pd.infer_freq(df.index))
# Out:
# None

# %%
df.head(7)
# Out:
#                Open     High      Low    Close
# Date
# 1991-01-02  1027.38  1027.38   999.26   999.26
# 1991-01-03   983.51   989.08   981.08   982.35
# 1991-01-07   982.81  1010.77   978.69  1010.77
# 1991-01-09  1007.66  1013.80   998.09  1008.52
# 1991-01-11  1000.51  1034.30   997.04  1034.30
# 1991-01-14  1012.80  1017.98  1004.91  1017.72
# 1991-01-23  1014.36  1014.36   998.77  1001.38

# %%
df=df.asfreq('D')
df
# Out:
#                 Open      High       Low     Close
# Date
# 1991-01-02   1027.38   1027.38    999.26    999.26
# 1991-01-03    983.51    989.08    981.08    982.35
# 1991-01-04       NaN       NaN       NaN       NaN
# 1991-01-05       NaN       NaN       NaN       NaN
# 1991-01-06       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...
# 2020-06-20       NaN       NaN       NaN       NaN
# 2020-06-21       NaN       NaN       NaN       NaN
# 2020-06-22  34892.03  35213.52  34794.40  34911.32
# 2020-06-23  35015.73  35482.16  34843.69  35430.43
# 2020-06-24  35679.74  35706.55  34794.93  34868.98
#
# [10767 rows x 4 columns]

# %%
df=df.fillna(method='ffill')

# %%
df.index
# Out:
# DatetimeIndex(['1991-01-02', '1991-01-03', '1991-01-04', '1991-01-05',
#                '1991-01-06', '1991-01-07', '1991-01-08', '1991-01-09',
#                '1991-01-10', '1991-01-11',
#                ...
#                '2020-06-15', '2020-06-16', '2020-06-17', '2020-06-18',
#                '2020-06-19', '2020-06-20', '2020-06-21', '2020-06-22',
#                '2020-06-23', '2020-06-24'],
#               dtype='datetime64[ns]', name='Date', length=10767, freq='D')

# %%
df.plot(figsize=(15,12));

# %%
df.shape
# Out:
# (10767, 4)

# %%
df.head()
# Out:
#                Open     High     Low   Close
# Date
# 1991-01-02  1027.38  1027.38  999.26  999.26
# 1991-01-03   983.51   989.08  981.08  982.35
# 1991-01-04   983.51   989.08  981.08  982.35
# 1991-01-05   983.51   989.08  981.08  982.35
# 1991-01-06   983.51   989.08  981.08  982.35

# %%
df.iloc[10591:].plot(figsize=(12,8));

# %%
df.iloc[10591:]['Close'].min()
# Out:
# 25981.24
